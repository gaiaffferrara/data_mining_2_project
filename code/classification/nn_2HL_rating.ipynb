# %%
# !pip install torchsummary
# !pip install pytorch-ignite

# %%
# !pip install shap

# %%
# # Installa PyTorch con supporto MPS
# !pip install torch torchvision torchaudio

# %% [markdown]
# # NN Pytorch - rating - 2 HIDDEN LAYER (64, 32)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch
import torch.nn.functional as F
import shap
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

from torchsummary import summary
from torch.nn.init import xavier_normal_
from torch.utils.data import TensorDataset, DataLoader, WeightedRandomSampler, Subset

from ignite.metrics import MeanSquaredError, MeanAbsoluteError, Metric

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import KFold, train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import torch
import torch.nn as nn
import torch.optim as optim

from torchsummary import summary
from torch.utils.data import TensorDataset, DataLoader

from ignite.metrics import Accuracy, Loss
from ignite.engine import Engine, Events, create_supervised_trainer, create_supervised_evaluator

# %% [markdown]
# ### Import dati

# %%
x_train = (pd.read_csv('../../rating/X_train_rating_no_out.csv')).drop('Unnamed: 0', axis =1)
y_train = (pd.read_csv('../../rating/y_train_rating_no_out.csv')).drop('Unnamed: 0', axis =1)

x_test = (pd.read_csv('../../rating/X_test_rating.csv')).drop('Unnamed: 0', axis =1)
y_test = (pd.read_csv('../../rating/y_test_rating.csv')).drop('Unnamed: 0', axis =1)

# %%
y_train = y_train['rating']
y_test = y_test['rating']

# %%
# log transformation delle seguenti colonne: runtimeminutes, numvotes, totalcredits, userrewtotal, totalmedia
cols = ['runtimeMinutes', 'numVotes', 'totalCredits', 'userReviewsTotal', 'totalMedia']

for col in cols:
    x_train[col] = np.log1p(x_train[col])
    x_test[col] = np.log1p(x_test[col])

# %%
scaler = StandardScaler()

num_cols = ['startYear', 'runtimeMinutes', 'numVotes', 'totalCredits', 'criticReviewsTotal', 'numRegions', 'userReviewsTotal',
        'companiesNumber', 'externalLinks', 'writerCredits',
        'directorsCredits', 'quotesTotal', 'totalMedia', 'totalNominations']

scaler.fit(x_train[num_cols])
# Out:
# StandardScaler()

# %%
x_train[num_cols] = scaler.transform(x_train[num_cols])
x_test[num_cols] = scaler.transform(x_test[num_cols])

# %% [markdown]
# ### Costruzione rete

# %%
x_train_split, x_val, y_train_split, y_val = train_test_split(x_train, y_train, test_size=0.3, random_state=42, stratify=y_train)

# %%
# Sottrai 1 a tutte le etichette perchè altrimenti dà errore
y_train_split = y_train_split - 1
y_val = y_val - 1
y_test = y_test - 1

# %%
x_train_tensor = torch.tensor(x_train_split.values, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train_split.values, dtype=torch.long)

x_val_tensor = torch.tensor(x_val.values, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val.to_numpy(), dtype=torch.long)

x_test_tensor = torch.tensor(x_test.values, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.long)

# %%
# Conta quanti esempi ci sono per ogni classe
class_counts = torch.bincount(y_train_tensor)
class_weights = 1.0 / class_counts.float()

# Assegna a ciascun campione il peso della sua classe
sample_weights = class_weights[y_train_tensor]

# Crea il sampler
sampler = WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(sample_weights),  # numero di campioni da estrarre per epoch
    replacement=True
)

# %%
train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
val_dataset = TensorDataset(x_val_tensor, y_val_tensor)
test_dataset = TensorDataset(x_test_tensor, y_test_tensor)

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    sampler=sampler
)

# %%
# train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=32)
test_loader = DataLoader(test_dataset, batch_size=32)

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class NNClassifier(nn.Module):

    def __init__(self,
                 input_dim, output_size
                , dropout_prob=0.3
                 ):
        super(NNClassifier, self).__init__()

        self.hidden1 = nn.Linear(input_dim, 256)
        self.hidden2 = nn.Linear(256, 128)
        self.output_layer = nn.Linear(128, output_size)

        self.relu = nn.ReLU()
        # self.tahn = nn.Tanh()
        self.dropout = nn.Dropout(p=dropout_prob)  # Dropout layer

    def forward(self, x):
        x = self.relu(self.hidden1(x))
        # x = self.tahn(self.hidden1(x))
        x = self.dropout(x)          # Applica Dropout dopo il primo hidden layer
        x = self.relu(self.hidden2(x))
        # x = self.tahn(self.hidden2(x))
        x = self.dropout(x)          # Applica Dropout dopo il secondo hidden layer
        x = self.output_layer(x)     # Output logits (CrossEntropyLoss gestisce Softmax)
        return x

# %%
input_size = x_train.shape[1] # ci devono essere tanti neuroni quante colonne da considerare
output_size = 10 # settato ad 10 perché l'output della classificazione sono 10 classi

# %%
from ignite.handlers import EarlyStopping, ModelCheckpoint
from ignite.contrib.handlers import global_step_from_engine
from ignite.engine import Engine, Events, create_supervised_trainer, create_supervised_evaluator
from ignite.metrics import Accuracy, Precision, Recall, ConfusionMatrix, Fbeta

# %%
model = NNClassifier(input_size, output_size)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
criterion = nn.CrossEntropyLoss()

# %%
trainer = create_supervised_trainer(model, optimizer, criterion, device)

# %%
val_metrics = {
    "accuracy": Accuracy(),
    "f1_macro": Fbeta(beta=1.0, average=True),
    "loss": Loss(criterion)
}

train_evaluator = create_supervised_evaluator(model, metrics=val_metrics, device=device)
val_evaluator = create_supervised_evaluator(model, metrics=val_metrics, device=device)

# --- Storico ---
training_history = {m: [] for m in val_metrics.keys()}
validation_history = {m: [] for m in val_metrics.keys()}

# %%
@trainer.on(Events.EPOCH_COMPLETED)
def log_training_results(trainer):
    train_evaluator.run(train_loader)
    metrics = train_evaluator.state.metrics

    training_history['loss'].append(metrics['loss'])
    training_history['accuracy'].append(metrics['accuracy'])
    training_history['f1_macro'].append(metrics['f1_macro'])

    print(f"Training Results - Epoch[{trainer.state.epoch}] "
          f"Loss: {metrics['loss']:.4f} "
          f"Acc: {metrics['accuracy']:.4f} "
          f"F1(macro): {metrics['f1_macro']:.4f}")


@trainer.on(Events.EPOCH_COMPLETED)
def log_validation_results(trainer):
    val_evaluator.run(val_loader)
    metrics = val_evaluator.state.metrics

    validation_history['loss'].append(metrics['loss'])
    validation_history['accuracy'].append(metrics['accuracy'])
    validation_history['f1_macro'].append(metrics['f1_macro'])

    print(f"Validation Results - Epoch[{trainer.state.epoch}] "
          f"Loss: {metrics['loss']:.4f} "
          f"Acc: {metrics['accuracy']:.4f} "
          f"F1(macro): {metrics['f1_macro']:.4f}")

# %%
from ignite.metrics import Accuracy

# Assicurati di avere f1 calcolata nel val_evaluator
def score_function(engine):
    metrics = engine.state.metrics
    return metrics['f1_macro']  # EarlyStopping massimizza questa metrica

# %%
handler = EarlyStopping(patience=50, score_function=score_function, trainer=trainer)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.5,
    patience=5
)

# Per ReduceLROnPlateau devi gestire lo scheduler manualmente
# perché ha bisogno di una metrica per decidere quando ridurre il LR
@val_evaluator.on(Events.EPOCH_COMPLETED)
def scheduler_step(engine):
    # Ottieni la loss di validazione dalle metriche
    val_loss = engine.state.metrics['loss']
    scheduler.step(val_loss)

@trainer.on(Events.EPOCH_COMPLETED)
def print_lr(engine):
    print("Learning Rate:", optimizer.param_groups[0]['lr'])

checkpoint = ModelCheckpoint(
    dirname='models',
    filename_prefix='best_EARLY',
    n_saved=1,
    create_dir=True,
    global_step_transform=global_step_from_engine(trainer),
    require_empty=False
)

val_evaluator.add_event_handler(Events.EPOCH_COMPLETED, handler)
val_evaluator.add_event_handler(Events.EPOCH_COMPLETED, checkpoint, {'model': model})

# %%
trainer.run(train_loader, max_epochs=100)
# Out:
# Training Results - Epoch[1] Loss: 1.5831 Acc: 0.4064 F1(macro): 0.3838
# Validation Results - Epoch[1] Loss: 1.8177 Acc: 0.2597 F1(macro): 0.1761
# Learning Rate: 0.001
# Training Results - Epoch[2] Loss: 1.4473 Acc: 0.4575 F1(macro): 0.4337
# Validation Results - Epoch[2] Loss: 1.7722 Acc: 0.2757 F1(macro): 0.1886
# Learning Rate: 0.001
# Training Results - Epoch[3] Loss: 1.3699 Acc: 0.4810 F1(macro): 0.4571
# Validation Results - Epoch[3] Loss: 1.7886 Acc: 0.2257 F1(macro): 0.1702
# Learning Rate: 0.001
# Training Results - Epoch[4] Loss: 1.3082 Acc: 0.5016 F1(macro): 0.4776
# Validation Results - Epoch[4] Loss: 1.7668 Acc: 0.2554 F1(macro): 0.1867
# Learning Rate: 0.001
# Training Results - Epoch[5] Loss: 1.2702 Acc: 0.5167 F1(macro): 0.4826
# Validation Results - Epoch[5] Loss: 1.7841 Acc: 0.2531 F1(macro): 0.1763
# Learning Rate: 0.001
# Training Results - Epoch[6] Loss: 1.2432 Acc: 0.5269 F1(macro): 0.4980
# Validation Results - Epoch[6] Loss: 1.7423 Acc: 0.2727 F1(macro): 0.1903
# Learning Rate: 0.001
# Training Results - Epoch[7] Loss: 1.2151 Acc: 0.5359 F1(macro): 0.5135
# Validation Results - Epoch[7] Loss: 1.7242 Acc: 0.2873 F1(macro): 0.2037
# Learning Rate: 0.001
# Training Results - Epoch[8] Loss: 1.1800 Acc: 0.5475 F1(macro): 0.5235
# Validation Results - Epoch[8] Loss: 1.6952 Acc: 0.2934 F1(macro): 0.2026
# Learning Rate: 0.001
# Training Results - Epoch[9] Loss: 1.1754 Acc: 0.5530 F1(macro): 0.5301
# Validation Results - Epoch[9] Loss: 1.7022 Acc: 0.2867 F1(macro): 0.2011
# Learning Rate: 0.001
# Training Results - Epoch[10] Loss: 1.1551 Acc: 0.5554 F1(macro): 0.5252
# Validation Results - Epoch[10] Loss: 1.7400 Acc: 0.2700 F1(macro): 0.1862
# Learning Rate: 0.001
# Training Results - Epoch[11] Loss: 1.1452 Acc: 0.5659 F1(macro): 0.5432
# Validation Results - Epoch[11] Loss: 1.6684 Acc: 0.3033 F1(macro): 0.2053
# Learning Rate: 0.001
# Training Results - Epoch[12] Loss: 1.1436 Acc: 0.5624 F1(macro): 0.5343
# Validation Results - Epoch[12] Loss: 1.7306 Acc: 0.2672 F1(macro): 0.1911
# Learning Rate: 0.001
# Training Results - Epoch[13] Loss: 1.1285 Acc: 0.5697 F1(macro): 0.5478
# Validation Results - Epoch[13] Loss: 1.6890 Acc: 0.2923 F1(macro): 0.2061
# Learning Rate: 0.001
# Training Results - Epoch[14] Loss: 1.1053 Acc: 0.5766 F1(macro): 0.5534
# Validation Results - Epoch[14] Loss: 1.6930 Acc: 0.2814 F1(macro): 0.2021
# Learning Rate: 0.001
# Training Results - Epoch[15] Loss: 1.1057 Acc: 0.5770 F1(macro): 0.5497
# Validation Results - Epoch[15] Loss: 1.7241 Acc: 0.2877 F1(macro): 0.2010
# Learning Rate: 0.001
# Training Results - Epoch[16] Loss: 1.0937 Acc: 0.5801 F1(macro): 0.5555
# Validation Results - Epoch[16] Loss: 1.7127 Acc: 0.2857 F1(macro): 0.2022
# Learning Rate: 0.001
# Training Results - Epoch[17] Loss: 1.0779 Acc: 0.5876 F1(macro): 0.5672
# Validation Results - Epoch[17] Loss: 1.6756 Acc: 0.2903 F1(macro): 0.2133
# Learning Rate: 0.0005
# Training Results - Epoch[18] Loss: 1.0544 Acc: 0.5981 F1(macro): 0.5775
# Validation Results - Epoch[18] Loss: 1.6744 Acc: 0.2901 F1(macro): 0.2120
# Learning Rate: 0.0005
# Training Results - Epoch[19] Loss: 1.0376 Acc: 0.5989 F1(macro): 0.5780
# Validation Results - Epoch[19] Loss: 1.6849 Acc: 0.2902 F1(macro): 0.2152
# Learning Rate: 0.0005
# Engine run is terminating due to exception:
# Engine run is terminating due to exception:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 trainer.run(train_loader, max_epochs=100)
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\engine\engine.py:905, in Engine.run(self, data, max_epochs, epoch_length)
#     902     self.state.dataloader = data
#     904 if self.interrupt_resume_enabled:
# --> 905     return self._internal_run()
#     906 else:
#     907     return self._internal_run_legacy()
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\engine\engine.py:948, in Engine._internal_run(self)
#     946     self._internal_run_generator = self._internal_run_as_gen()
#     947 try:
# --> 948     return next(self._internal_run_generator)
#     949 except StopIteration as out:
#     950     self._internal_run_generator = None
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\engine\engine.py:1023, in Engine._internal_run_as_gen(self)
#    1021     self._dataloader_iter = None
#    1022     self.logger.error(f"Engine run is terminating due to exception: {e}")
# -> 1023     self._handle_exception(e)
#    1025 self._dataloader_iter = None
#    1026 return self.state
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\engine\engine.py:660, in Engine._handle_exception(self, e)
#     658     self._fire_event(Events.EXCEPTION_RAISED, e)
#     659 else:
# --> 660     raise e
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\engine\engine.py:979, in Engine._internal_run_as_gen(self)
#     977 if self.should_terminate_single_epoch != "skip_epoch_completed":  # type: ignore[comparison-overlap]
#     978     handlers_start_time = time.time()
# --> 979     self._fire_event(Events.EPOCH_COMPLETED)
#     980     epoch_time_taken += time.time() - handlers_start_time
#     981     # update time wrt handlers
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\engine\engine.py:435, in Engine._fire_event(self, event_name, *event_args, **event_kwargs)
#     433 kwargs.update(event_kwargs)
#     434 first, others = ((args[0],), args[1:]) if (args and args[0] == self) else ((), args)
# --> 435 func(*first, *(event_args + others), **kwargs)
#
# Cell In[127], line 3, in log_training_results(trainer)
#       1 @trainer.on(Events.EPOCH_COMPLETED)
#       2 def log_training_results(trainer):
# ----> 3     train_evaluator.run(train_loader)
#       4     metrics = train_evaluator.state.metrics
#       6     training_history['loss'].append(metrics['loss'])
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\engine\engine.py:905, in Engine.run(self, data, max_epochs, epoch_length)
#     902     self.state.dataloader = data
#     904 if self.interrupt_resume_enabled:
# --> 905     return self._internal_run()
#     906 else:
#     907     return self._internal_run_legacy()
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\engine\engine.py:948, in Engine._internal_run(self)
#     946     self._internal_run_generator = self._internal_run_as_gen()
#     947 try:
# --> 948     return next(self._internal_run_generator)
#     949 except StopIteration as out:
#     950     self._internal_run_generator = None
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\engine\engine.py:1023, in Engine._internal_run_as_gen(self)
#    1021     self._dataloader_iter = None
#    1022     self.logger.error(f"Engine run is terminating due to exception: {e}")
# -> 1023     self._handle_exception(e)
#    1025 self._dataloader_iter = None
#    1026 return self.state
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\engine\engine.py:660, in Engine._handle_exception(self, e)
#     658     self._fire_event(Events.EXCEPTION_RAISED, e)
#     659 else:
# --> 660     raise e
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\engine\engine.py:972, in Engine._internal_run_as_gen(self)
#     969 if self._dataloader_iter is None:
#     970     self._setup_engine()
# --> 972 epoch_time_taken += yield from self._run_once_on_dataset_as_gen()
#     974 # time is available for handlers but must be updated after fire
#     975 self.state.times[Events.EPOCH_COMPLETED.name] = epoch_time_taken
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\engine\engine.py:1111, in Engine._run_once_on_dataset_as_gen(self)
#    1108 yield from self._maybe_terminate_or_interrupt()
#    1110 self.state.output = self._process_function(self, self.state.batch)
# -> 1111 self._fire_event(Events.ITERATION_COMPLETED)
#    1112 yield from self._maybe_terminate_or_interrupt()
#    1114 if self.state.epoch_length is not None and iter_counter == self.state.epoch_length:
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\engine\engine.py:435, in Engine._fire_event(self, event_name, *event_args, **event_kwargs)
#     433 kwargs.update(event_kwargs)
#     434 first, others = ((args[0],), args[1:]) if (args and args[0] == self) else ((), args)
# --> 435 func(*first, *(event_args + others), **kwargs)
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\metrics\metric.py:475, in Metric.iteration_completed(self, engine)
#     473         self.update((tensor_o1, tensor_o2))
#     474 else:
# --> 475     self.update(output)
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\metrics\metric.py:870, in reinit__is_reduced.<locals>.wrapper(self, *args, **kwargs)
#     868 @wraps(func)
#     869 def wrapper(self: Metric, *args: Any, **kwargs: Any) -> None:
# --> 870     func(self, *args, **kwargs)
#     871     if "_result" in self.__dict__:
#     872         self._result = None
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\metrics\recall.py:227, in Recall.update(self, output)
#     225 self._check_shape(output)
#     226 self._check_type(output)
# --> 227 _, y, correct = self._prepare_output(output)
#     229 if self._average == "samples":
#     230     actual_positives = y.sum(dim=1)
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\ignite\metrics\precision.py:70, in _BasePrecisionRecall._prepare_output(self, output)
#      65 if self._type == "multiclass" and y.max() + 1 > num_classes:
#      66     raise ValueError(
#      67         f"y_pred contains fewer classes than y. Number of classes in the prediction is {num_classes}"
#      68         f" and an element in y has invalid class = {y.max().item() + 1}."
#      69     )
# ---> 70 y = y.view(-1)
#      71 if self._type == "binary" and self._average is False:
#      72     y_pred = y_pred.view(-1)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(training_history['loss']) + 1)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

# --- Plot Model Loss ---
axes[0].plot(epochs, training_history['loss'], label='train')
axes[0].plot(epochs, validation_history['loss'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Model Loss over epochs')
axes[0].legend()

# --- Plot Macro F1 ---
axes[1].plot(epochs, training_history['f1_macro'], label='train')
axes[1].plot(epochs, validation_history['f1_macro'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('F1 (macro)')
axes[1].set_title('Macro F1 over epochs')
axes[1].legend()

fig.tight_layout()
plt.show()

# %% [markdown]
# ### VALIDATION

# %%
model.eval()  # importantissimo: disabilita dropout e batchnorm
# Out:
# NNClassifier(
#   (hidden1): Linear(in_features=58, out_features=256, bias=True)
#   (hidden2): Linear(in_features=256, out_features=128, bias=True)
#   (output_layer): Linear(in_features=128, out_features=10, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# NNClassifier(
#   (hidden1): Linear(in_features=58, out_features=256, bias=True)
#   (hidden2): Linear(in_features=256, out_features=128, bias=True)
#   (output_layer): Linear(in_features=128, out_features=10, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %%
with torch.no_grad():  # disabilita il calcolo dei gradienti
    logits = model(x_val_tensor)          # output layer, logits
    probs = torch.softmax(logits, dim=1)  # probabilità
    preds = torch.argmax(probs, dim=1)    # classe predetta

# %%
probs = probs.cpu().numpy()
preds = preds.cpu().numpy()

# %%
report = classification_report(y_val, preds, target_names=[f'Rating {i}' for i in range(1, 11)])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     Rating 1       0.02      0.47      0.03        38
#     Rating 2       0.02      0.28      0.04       137
#     Rating 3       0.06      0.25      0.09       359
#     Rating 4       0.14      0.33      0.19      1044
#     Rating 5       0.24      0.22      0.23      2545
#     Rating 6       0.38      0.21      0.27      5735
#     Rating 7       0.43      0.12      0.19      9525
#     Rating 8       0.45      0.45      0.45      8354
#     Rating 9       0.16      0.21      0.18      2475
#    Rating 10       0.05      0.67      0.10       293
#
#     accuracy                           0.26     30505
#    macro avg       0.19      0.32      0.18     30505
# weighted avg       0.37      0.26      0.28     30505

# %%
cm = confusion_matrix(y_val, preds)

plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[f'{i}' for i in range(1, 10)],
            yticklabels=[f'{i}' for i in range(11)])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('CM Neural Network - rating')
plt.show()

# %% [markdown]
# ### DEBUGGING

# %%
# idxs = []
# for c in torch.unique(y_train_tensor):
#     class_idxs = (y_train_tensor == c).nonzero(as_tuple=True)[0]
#     idxs.extend(class_idxs[:20])  # prendi max 20 esempi per classe

# small_dataset = Subset(train_dataset, idxs)
# small_loader = DataLoader(small_dataset, batch_size=16, shuffle=True)

# print(f"Subset creato con {len(small_dataset)} campioni")

# # =======================================
# # 3. Modello (tua struttura senza dropout)
# # =======================================
# class NNClassifier(nn.Module):
#     def __init__(self, input_dim, output_size, dropout_prob=0.0):
#         super(NNClassifier, self).__init__()
#         self.hidden1 = nn.Linear(input_dim, 256)
#         self.hidden2 = nn.Linear(256, 128)
#         self.output_layer = nn.Linear(128, output_size)
#         self.relu = nn.ReLU()
#         self.dropout = nn.Dropout(p=dropout_prob)

#     def forward(self, x):
#         x = self.relu(self.hidden1(x))
#         x = self.dropout(x)
#         x = self.relu(self.hidden2(x))
#         x = self.dropout(x)
#         x = self.output_layer(x)
#         return x

# input_dim   = x_train_tensor.shape[1]
# output_size = len(torch.unique(y_train_tensor))

# model = NNClassifier(input_dim=input_dim, output_size=output_size, dropout_prob=0.0).to(device)

# # =======================================
# # 4. Loss e ottimizzatore
# # =======================================
# criterion = nn.CrossEntropyLoss()
# optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=0.0)

# # =======================================
# # 5. Training loop per overfitting test
# # =======================================
# for epoch in range(30):  # aumentiamo un po' le epoche
#     model.train()
#     running_loss, correct, total = 0.0, 0, 0
    
#     for xb, yb in small_loader:
#         xb, yb = xb.to(device), yb.to(device)
#         optimizer.zero_grad()
#         logits = model(xb)
#         loss = criterion(logits, yb)
#         loss.backward()
#         optimizer.step()

#         running_loss += loss.item() * xb.size(0)
#         _, preds = torch.max(logits, 1)
#         correct += (preds == yb).sum().item()
#         total += yb.size(0)
    
#     acc = correct / total
#     avg_loss = running_loss / total
#     print(f"Epoch {epoch+1:02d}: Loss {avg_loss:.4f}, Accuracy {acc:.4f}")

# %% [markdown]
# ### RANDOMIZED

# %%
# import torch
# import torch.nn as nn
# import torch.optim as optim
# import random
# from sklearn.metrics import accuracy_score

# # ----------------------------
# # 1. Modello a due hidden layer
# # ----------------------------
# class TwoLayerNet(nn.Module):
#     def __init__(self, input_dim, hidden1, hidden2, output_dim, dropout_prob=0.3):
#         super(TwoLayerNet, self).__init__()
#         self.hidden1 = nn.Linear(input_dim, hidden1)
#         self.hidden2 = nn.Linear(hidden1, hidden2)
#         self.output = nn.Linear(hidden2, output_dim)
#         self.relu = nn.ReLU()
#         self.dropout = nn.Dropout(dropout_prob)

#     def forward(self, x):
#         x = self.relu(self.hidden1(x))
#         x = self.dropout(x)
#         x = self.relu(self.hidden2(x))
#         x = self.dropout(x)
#         return self.output(x)

# # ----------------------------
# # 2. Training loop
# # ----------------------------
# def train_and_evaluate(params, train_loader, val_loader, input_dim, output_dim, device):
#     model = TwoLayerNet(
#         input_dim=input_dim,
#         hidden1=params['hidden1'],
#         hidden2=params['hidden2'],
#         output_dim=output_dim,
#         dropout_prob=params['dropout']
#     ).to(device)

#     criterion = nn.CrossEntropyLoss()
#     optimizer = optim.SGD(model.parameters(), lr=params['lr'], weight_decay=1e-4)

#     # Training
#     for epoch in range(params['epochs']):
#         model.train()
#         for xb, yb in train_loader:
#             xb, yb = xb.to(device), yb.to(device)
#             optimizer.zero_grad()
#             outputs = model(xb)
#             loss = criterion(outputs, yb)
#             loss.backward()
#             optimizer.step()

#     # Evaluation
#     model.eval()
#     all_preds, all_labels = [], []
#     with torch.no_grad():
#         for xb, yb in val_loader:
#             xb, yb = xb.to(device), yb.to(device)
#             logits = model(xb)
#             preds = torch.argmax(logits, dim=1)
#             all_preds.extend(preds.cpu().numpy())
#             all_labels.extend(yb.cpu().numpy())

#     acc = accuracy_score(all_labels, all_preds)
#     return acc

# # ----------------------------
# # 3. Randomized search
# # ----------------------------
# def randomized_search(param_grid, n_iter, train_loader, val_loader, input_dim, output_dim, device):
#     results = []
#     for i in range(n_iter):
#         params = {
#             'hidden1': random.choice(param_grid['hidden1']),
#             'hidden2': random.choice(param_grid['hidden2']),
#             'dropout': random.choice(param_grid['dropout']),
#             'lr': random.choice(param_grid['lr']),
#             'epochs': random.choice(param_grid['epochs'])
#         }
#         acc = train_and_evaluate(params, train_loader, val_loader, input_dim, output_dim, device)
#         results.append((params, acc))
#         print(f"Trial {i+1}/{n_iter}: {params} -> acc={acc:.4f}")
#     return results

# # ----------------------------
# # 4. Esempio di utilizzo coi tuoi loader
# # ----------------------------
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# param_grid = {
#     'hidden1': [64, 128, 256],
#     'hidden2': [32, 64, 128],
#     'dropout': [0.2, 0.3, 0.5],
#     'lr': [1e-2, 1e-3, 1e-4],
#     'epochs': [100, 150, 200]  # puoi aumentare
# }

# input_dim = x_train_tensor.shape[1]
# output_dim = len(torch.unique(y_train_tensor))

# results = randomized_search(param_grid, n_iter=5,
#                             train_loader=train_loader,
#                             val_loader=val_loader,
#                             input_dim=input_dim,
#                             output_dim=output_dim,
#                             device=device)

# best_params, best_acc = max(results, key=lambda x: x[1])
# print("\nMigliori iperparametri:", best_params)
# print("Accuratezza val:", best_acc)

# %% [markdown]
# ### PER EXPLAINABILITY CON SHAP

# %%
# def predict_proba(model, X, device='cpu', batch_size=64):
#     model.eval()
#     probs_list = []

#     with torch.no_grad():
#         for i in range(0, len(X), batch_size):
#             x_batch = torch.tensor(X[i:i+batch_size], dtype=torch.float32).to(device)
#             logits = model(x_batch)            # output layer, logits
#             probs = F.softmax(logits, dim=1)   # converti in probabilità
#             probs_list.append(probs.cpu())

#     return torch.cat(probs_list, dim=0).numpy()

# %%
# # esempio: shap.DeepExplainer o KernelExplainer
# X_background = x_train_tensor[np.random.choice(x_train_tensor.shape[0], 100, replace=False)]
# explainer = shap.KernelExplainer(lambda x: predict_proba(model, x, device=device), X_background)
# shap_values = explainer.shap_values(x_test)
