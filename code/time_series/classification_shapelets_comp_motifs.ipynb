# %% [markdown]
# # CLASSIFICATION WITH SHAPELETS + shapelets analysis

# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from tslearn.shapelets import ShapeletModel, grabocka_params_to_shapelet_size_dict
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train = pd.read_csv("X_train.csv")
X_test = pd.read_csv("X_test.csv")
y_train = pd.read_csv("y_train.csv")
y_test = pd.read_csv("y_test.csv")
X_train = X_train.iloc[:, :100]
X_test = X_test.iloc[:, :100]
y_train = y_train.values.ravel()
y_test = y_test.values.ravel()

# %%
scaler_ts = MinMaxScaler()
X_train_scaled = scaler_ts.fit_transform(X_train)
X_test_scaled = scaler_ts.transform(X_test)

# %%
# Calcola shapelet_sizes con la funzione grabocka_params_to_shapelet_size_dict
shapelet_sizes = grabocka_params_to_shapelet_size_dict(
    n_ts=X_train_scaled.shape[0],
    ts_sz=X_train_scaled.shape[1],
    n_classes=len(np.unique(y_train)),
    l=0.1,    # lunghezza media shapelet = 10% della serie temporale
    r=10      # shapelet per classe
)

print("Shapelet sizes dict:", shapelet_sizes)
# Out:
# Shapelet sizes dict: {10: 5, 20: 5, 30: 5, 40: 5, 50: 5, 60: 5, 70: 4, 80: 4, 90: 4, 100: 3}

# %%
shp_model = ShapeletModel(
    n_shapelets_per_size=shapelet_sizes,
    optimizer='adam',
    weight_regularizer=0.01,
    max_iter=100,
    random_state=42,
    verbose=1
)

shp_model.fit(X_train_scaled, y_train)
X_shp_train = shp_model.transform(X_train_scaled)
X_shp_test = shp_model.transform(X_test_scaled)
# Out:
# c:\Users\Gagia\anaconda3\Lib\site-packages\tslearn\shapelets\shapelets.py:353: FutureWarning: The default value for 'scale' is set to False in version 0.4 to ensure backward compatibility, but is likely to change in a future version.
#   warnings.warn("The default value for 'scale' is set to False "
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - categorical_accuracy: 0.2043 - categorical_crossentropy: 1.6184 - loss: 1.7007
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.2043 - categorical_crossentropy: 1.6123 - loss: 1.6923
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - categorical_accuracy: 0.2043 - categorical_crossentropy: 1.6063 - loss: 1.6842
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - categorical_accuracy: 0.2043 - categorical_crossentropy: 1.6004 - loss: 1.6763
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.2068 - categorical_crossentropy: 1.5946 - loss: 1.6686
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.2068 - categorical_crossentropy: 1.5889 - loss: 1.6610
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.2282 - categorical_crossentropy: 1.5834 - loss: 1.6537
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - categorical_accuracy: 0.2358 - categorical_crossentropy: 1.5779 - loss: 1.6465
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.3026 - categorical_crossentropy: 1.5725 - loss: 1.6395
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - categorical_accuracy: 0.3115 - categorical_crossentropy: 1.5672 - loss: 1.6326
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - categorical_accuracy: 0.3165 - categorical_crossentropy: 1.5619 - loss: 1.6259
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - categorical_accuracy: 0.3253 - categorical_crossentropy: 1.5567 - loss: 1.6193
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - categorical_accuracy: 0.3279 - categorical_crossentropy: 1.5516 - loss: 1.6128
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - categorical_accuracy: 0.3291 - categorical_crossentropy: 1.5464 - loss: 1.6064
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 0.3430 - categorical_crossentropy: 1.5413 - loss: 1.6001
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.3493 - categorical_crossentropy: 1.5362 - loss: 1.5939
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - categorical_accuracy: 0.3745 - categorical_crossentropy: 1.5312 - loss: 1.5877
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - categorical_accuracy: 0.3821 - categorical_crossentropy: 1.5261 - loss: 1.5817
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - categorical_accuracy: 0.3972 - categorical_crossentropy: 1.5210 - loss: 1.5757
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - categorical_accuracy: 0.4136 - categorical_crossentropy: 1.5159 - loss: 1.5697
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.4451 - categorical_crossentropy: 1.5109 - loss: 1.5638
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - categorical_accuracy: 0.4464 - categorical_crossentropy: 1.5058 - loss: 1.5580
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - categorical_accuracy: 0.4414 - categorical_crossentropy: 1.5007 - loss: 1.5522
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - categorical_accuracy: 0.4439 - categorical_crossentropy: 1.4956 - loss: 1.5464
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.4515 - categorical_crossentropy: 1.4904 - loss: 1.5407
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.4853 - loss: 1.5351
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.4552 - categorical_crossentropy: 1.4802 - loss: 1.5295
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - categorical_accuracy: 0.4527 - categorical_crossentropy: 1.4750 - loss: 1.5239
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - categorical_accuracy: 0.4590 - categorical_crossentropy: 1.4699 - loss: 1.5184
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.4615 - categorical_crossentropy: 1.4648 - loss: 1.5129
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.4641 - categorical_crossentropy: 1.4596 - loss: 1.5075
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.4545 - loss: 1.5021
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - categorical_accuracy: 0.4666 - categorical_crossentropy: 1.4494 - loss: 1.4969
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.4641 - categorical_crossentropy: 1.4444 - loss: 1.4916
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.4666 - categorical_crossentropy: 1.4393 - loss: 1.4865
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.4666 - categorical_crossentropy: 1.4344 - loss: 1.4814
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.4641 - categorical_crossentropy: 1.4294 - loss: 1.4764
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - categorical_accuracy: 0.4641 - categorical_crossentropy: 1.4245 - loss: 1.4715
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.4197 - loss: 1.4666
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.4603 - categorical_crossentropy: 1.4150 - loss: 1.4619
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.4615 - categorical_crossentropy: 1.4103 - loss: 1.4573
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.4615 - categorical_crossentropy: 1.4057 - loss: 1.4527
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.4603 - categorical_crossentropy: 1.4013 - loss: 1.4483
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.4603 - categorical_crossentropy: 1.3969 - loss: 1.4440
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.4590 - categorical_crossentropy: 1.3926 - loss: 1.4398
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3884 - loss: 1.4358
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3844 - loss: 1.4318
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3805 - loss: 1.4280
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3767 - loss: 1.4243
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3730 - loss: 1.4207
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3694 - loss: 1.4172
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3660 - loss: 1.4139
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3627 - loss: 1.4106
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3595 - loss: 1.4075
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3564 - loss: 1.4045
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3535 - loss: 1.4016
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3506 - loss: 1.3987
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3479 - loss: 1.3960
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3452 - loss: 1.3934
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3427 - loss: 1.3909
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3403 - loss: 1.3884
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.4578 - categorical_crossentropy: 1.3379 - loss: 1.3861
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.4590 - categorical_crossentropy: 1.3357 - loss: 1.3838
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - categorical_accuracy: 0.4590 - categorical_crossentropy: 1.3335 - loss: 1.3816
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.4590 - categorical_crossentropy: 1.3314 - loss: 1.3794
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.4590 - categorical_crossentropy: 1.3294 - loss: 1.3774
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - categorical_accuracy: 0.4603 - categorical_crossentropy: 1.3275 - loss: 1.3754
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - categorical_accuracy: 0.4603 - categorical_crossentropy: 1.3256 - loss: 1.3734
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.4603 - categorical_crossentropy: 1.3238 - loss: 1.3715
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.4603 - categorical_crossentropy: 1.3220 - loss: 1.3697
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - categorical_accuracy: 0.4603 - categorical_crossentropy: 1.3204 - loss: 1.3680
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - categorical_accuracy: 0.4615 - categorical_crossentropy: 1.3187 - loss: 1.3662
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.4603 - categorical_crossentropy: 1.3172 - loss: 1.3646
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.4603 - categorical_crossentropy: 1.3156 - loss: 1.3629
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.4615 - categorical_crossentropy: 1.3142 - loss: 1.3614
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.3127 - loss: 1.3598
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.3114 - loss: 1.3584
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.3100 - loss: 1.3569
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.3087 - loss: 1.3555
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.3075 - loss: 1.3541
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.3063 - loss: 1.3528
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.3051 - loss: 1.3515
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.3040 - loss: 1.3502
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.3029 - loss: 1.3490
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - categorical_accuracy: 0.4615 - categorical_crossentropy: 1.3018 - loss: 1.3478
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.3008 - loss: 1.3467
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - categorical_accuracy: 0.4641 - categorical_crossentropy: 1.2998 - loss: 1.3455
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.4641 - categorical_crossentropy: 1.2988 - loss: 1.3444
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.2979 - loss: 1.3433
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.2969 - loss: 1.3423
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.2961 - loss: 1.3412
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.2952 - loss: 1.3402
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.2943 - loss: 1.3393
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.2935 - loss: 1.3383
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.2927 - loss: 1.3374
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.2920 - loss: 1.3365
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.2912 - loss: 1.3356
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.2905 - loss: 1.3347
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.2898 - loss: 1.3338
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - categorical_accuracy: 0.4628 - categorical_crossentropy: 1.2891 - loss: 1.3330
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 336ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
# Addestra RandomForest SENZA TUNING
rf = RandomForestClassifier(random_state=42)
rf.fit(X_shp_train, y_train)

# Predizione
y_pred = rf.predict(X_shp_test)

# Valutazione
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.38      0.21      0.27        39
#          2.0       0.45      0.67      0.54       116
#          3.0       0.05      0.01      0.02        70
#          4.0       0.53      0.59      0.56       113
#
#     accuracy                           0.45       341
#    macro avg       0.28      0.30      0.28       341
# weighted avg       0.38      0.45      0.40       341
# c:\Users\Gagia\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Gagia\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Gagia\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#PARAMETRI DA GRIDSEARCH
clf = RandomForestClassifier(criterion= 'gini', max_depth= 10, max_features= 'log2', min_samples_leaf=2, 
                             min_samples_split= 10, n_estimators= 100, random_state=42,  class_weight='balanced')
clf.fit(X_shp_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10,
#                        max_features='log2', min_samples_leaf=2,
#                        min_samples_split=10, random_state=42)

# %%
y_pred_tr = clf.predict(X_shp_train)
print("train CR")
print(classification_report(y_train, y_pred_tr))
# Out:
# train CR
#               precision    recall  f1-score   support
#
#          0.0       0.88      1.00      0.93         7
#          1.0       0.84      0.96      0.89        89
#          2.0       0.81      0.91      0.85       271
#          3.0       0.92      0.90      0.91       162
#          4.0       0.95      0.80      0.87       264
#
#     accuracy                           0.87       793
#    macro avg       0.88      0.91      0.89       793
# weighted avg       0.88      0.87      0.87       793

# %%
y_pred_ts = clf.predict(X_shp_test)
print("test CR")
print(classification_report(y_test, y_pred_ts))
# Out:
# test CR
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.42      0.33      0.37        39
#          2.0       0.44      0.66      0.53       116
#          3.0       0.21      0.13      0.16        70
#          4.0       0.58      0.47      0.52       113
#
#     accuracy                           0.45       341
#    macro avg       0.33      0.32      0.32       341
# weighted avg       0.43      0.45      0.43       341
# c:\Users\Gagia\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Gagia\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Gagia\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import confusion_matrix

# Calcola la confusion matrix
cm = confusion_matrix(y_test, y_pred_ts)

labels = ["Low", "Medium Low", "Medium", "Medium High", "High"]

# Visualizza con heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels,
            yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('CM - Random Forest with shapelets')
plt.show()

# %%
import joblib

# Salva il modello
joblib.dump(shp_model, "shp_model.pkl")

# Salva anche le trasformazioni se vuoi
joblib.dump(X_shp_train, "X_shp_train.pkl")
joblib.dump(X_shp_test, "X_shp_test.pkl")
# Out:
# ['X_shp_test.pkl']

# %%
import numpy as np

# Estrai le shapelet dal modello
shapelets = shp_model.shapelets_as_time_series_

# Salva in un file .npy
np.save("shapelets.npy", shapelets)

# %% [markdown]
# <!-- ### Analisi shapelets -->

# %% [markdown]
# ### Analisi shapelets vs motifs

# %%
importances = clf.feature_importances_
importances
# Out:
# array([0.04100143, 0.03088961, 0.02097947, 0.02228583, 0.02711015,
#        0.01619671, 0.02282623, 0.01737969, 0.02835943, 0.01187206,
#        0.03110211, 0.02802694, 0.01774925, 0.02533927, 0.01623642,
#        0.01521253, 0.03518722, 0.02891274, 0.02072014, 0.02509873,
#        0.02057541, 0.01619872, 0.01664573, 0.01997253, 0.01941769,
#        0.03204959, 0.00960074, 0.01592039, 0.03123684, 0.01929721,
#        0.02908839, 0.01852967, 0.01929869, 0.02390325, 0.01823822,
#        0.01939261, 0.01390172, 0.02843311, 0.02456463, 0.01674443,
#        0.02082568, 0.01318233, 0.02533487, 0.02840348, 0.01675815])

# %%
indices = np.argsort(importances)[::-1]

# Stampa le prime 10 più importanti
for i in range(10):
    print(f"Shapelet {indices[i]} - Importance: {importances[indices[i]]:.4f}")
# Out:
# Shapelet 0 - Importance: 0.0410
# Shapelet 16 - Importance: 0.0352
# Shapelet 25 - Importance: 0.0320
# Shapelet 28 - Importance: 0.0312
# Shapelet 10 - Importance: 0.0311
# Shapelet 1 - Importance: 0.0309
# Shapelet 30 - Importance: 0.0291
# Shapelet 17 - Importance: 0.0289
# Shapelet 37 - Importance: 0.0284
# Shapelet 43 - Importance: 0.0284

# %%
import numpy as np

# X_shp_train.shape = (n_samples, n_shapelets)
shapelet_idx = 0  # esempio
mean_dist_per_class = []
for c in np.unique(y_train):
    mean_dist_per_class.append(np.mean(X_shp_train[y_train==c, shapelet_idx]))
    
print(mean_dist_per_class)
# Out:
# [0.015183915, 0.014930741, 0.015332905, 0.016025376, 0.01653942]

# %%
import numpy as np

# X_shp_train.shape = (n_samples, n_shapelets)
# y_train.shape = (n_samples,)

result = {}

for c in np.unique(y_train):
    mean_dists = []
    for shapelet_idx in range(X_shp_train.shape[1]):
        mean_val = np.mean(X_shp_train[y_train == c, shapelet_idx])
        mean_dists.append((shapelet_idx, mean_val))
    
    # ordino per distanza media crescente
    mean_dists.sort(key=lambda x: x[1])
    
    # prendo i primi 3 indici
    top3 = [idx for idx, _ in mean_dists[:3]]
    
    result[c] = top3

print(result)
# Out:
# {0.0: [3, 30, 14], 1.0: [3, 14, 30], 2.0: [3, 14, 1], 3.0: [3, 14, 1], 4.0: [3, 14, 1]}

# %%
shapelets = shp_model.shapelets_as_time_series_
shape = shapelets[0]
shape_clean = shape[~np.isnan(shape)]
shape_clean
# Out:
# array([0.10409354, 0.02839074, 0.37553555, 0.31767145, 0.08694325,
#        0.02425086, 0.33711153, 0.36105978, 0.12870429, 0.12011517])

# %%
import numpy as np
import matplotlib.pyplot as plt

# esempio: shapelet con NaN come quella che hai mostrato
shape = np.array([
    0.10409354, 0.02839074, 0.37553555, 0.31767145, 0.08694325,
    0.02425086, 0.33711153, 0.36105978, 0.12870429, 0.12011517
])

# rimuovo i NaN
# shape_clean = shape[~np.isnan(shape)]

# creo l'asse temporale (lunghezza della shapelet)
time_axis = np.arange(len(shape_clean))

# plot
plt.figure(figsize=(6,3))
plt.plot(time_axis, shape_clean, marker="o", linestyle="-", color="b")
plt.title("Forma della shapelet")
plt.xlabel("Time index")
plt.ylabel("Valore")
plt.grid(True)
plt.show()

# %%
for c in np.unique(y_train):
    mean_dists = []
    for shapelet_idx in range(X_shp_train.shape[1]):
        mean_val = np.mean(X_shp_train[y_train == c, shapelet_idx])
        mean_dists.append((shapelet_idx, mean_val))
    
    mean_dists.sort(key=lambda x: x[1])
    print(f"Classe {c}: top 5 -> {mean_dists[:5]}")
# Out:
# Classe 0.0: top 5 -> [(3, 0.0013225216), (30, 0.002940928), (14, 0.0043184194), (1, 0.0054892814), (0, 0.015183915)]
# Classe 1.0: top 5 -> [(3, 0.0012854417), (14, 0.0033617178), (30, 0.0036297196), (1, 0.004152129), (0, 0.014930741)]
# Classe 2.0: top 5 -> [(3, 0.0015935603), (14, 0.0033276037), (1, 0.004420869), (30, 0.0045421897), (13, 0.014124328)]
# Classe 3.0: top 5 -> [(3, 0.0017512758), (14, 0.003921811), (1, 0.0063315304), (30, 0.013329612), (13, 0.015804876)]
# Classe 4.0: top 5 -> [(3, 0.0021283964), (14, 0.0052791312), (1, 0.006056098), (0, 0.01653942), (13, 0.016749233)]

# %%
shapelets = shp_model.shapelets_as_time_series_

# %%
import numpy as np
import matplotlib.pyplot as plt

# Lista per tenere traccia delle shapelet già assegnate
used_shapelets = set()

# Ciclo sulle classi
for class_idx in range(1, 6):  # classi da 1 a 5
    # media delle distanze shapelet/class
    mean_dists = np.array([np.mean(X_shp_train[y_train==class_idx, i]) for i in range(X_shp_train.shape[1])])

    # ordina gli indici delle shapelet in base alla distanza media
    sorted_idx = np.argsort(mean_dists)

    # seleziona le prime 3 shapelet non ancora usate
    topk_idx = []
    for idx in sorted_idx:
        if idx not in used_shapelets:
            topk_idx.append(idx)
            used_shapelets.add(idx)
        if len(topk_idx) >= 3:
            break

    print(f"Top 3 shapelets uniche per classe {class_idx}: {topk_idx}")

    # plot delle top 3 shapelet
    plt.figure(figsize=(12, 3))
    for j, shp_idx in enumerate(topk_idx):
        plt.subplot(1, 3, j+1)
        plt.plot(shapelets[shp_idx])
        plt.title(f"Shapelet {shp_idx}")
        plt.grid(True)
    plt.suptitle(f"Top 3 shapelets per classe {class_idx}")
    plt.tight_layout()
    plt.show()
# Out:
# Top 3 shapelets uniche per classe 1: [3, 14, 30]
# Top 3 shapelets uniche per classe 2: [1, 13, 0]
# Top 3 shapelets uniche per classe 3: [19, 7, 28]
# Top 3 shapelets uniche per classe 4: [10, 17, 2]
# c:\Users\Gagia\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Gagia\anaconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# Top 3 shapelets uniche per classe 5: [24, 25, 26]

# %% [markdown]
# ##### più giusto ma restituisce nan per distanza

# %% [markdown]
# <!-- #### con stumpy -->

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import stumpy
# from dtaidistance import dtw

# # Supponiamo di avere già:
# # X_train_scaled: array delle serie temporali scalate
# # y_train: array delle etichette
# # X_shp_train: distanze shapelet vs serie temporali
# # shapelets: lista di shapelet estratte

# def top_k_shapelets_per_class_func(X_shp_train, y_train, topk=3):
#     """Calcola le top-k shapelet uniche per classe"""
#     used_shapelets = set()
#     all_topk = []
#     for class_idx in range(1, 6):  # classi 1-5
#         mean_dists = np.array([np.mean(X_shp_train[y_train==class_idx, i]) 
#                                for i in range(X_shp_train.shape[1])])
#         sorted_idx = np.argsort(mean_dists)
        
#         topk_idx = []
#         for idx in sorted_idx:
#             if idx not in used_shapelets:
#                 topk_idx.append(idx)
#                 used_shapelets.add(idx)
#             if len(topk_idx) >= topk:
#                 break
#         all_topk.append(topk_idx)
#     return all_topk

# # Calcolo top 3 shapelet per classe
# topk_shapelets_per_class = top_k_shapelets_per_class_func(X_shp_train, y_train, topk=3)

# # Loop su ciascuna classe
# for class_idx in np.unique(y_train):
#     print(f"\n=== Classe {class_idx} ===")
    
#     # Seleziona le serie della classe
#     X_class = X_train_scaled[y_train == class_idx]
    
#     # Lunghezza dei motif = lunghezza della shapelet più rappresentativa della classe
#     motif_len = shapelets[int(topk_shapelets_per_class[int(class_idx)-1][0])].shape[0]
    
#     # Concatenazione delle serie
#     ts_concat = np.concatenate(X_class)
    
#     # Calcolo matrix profile con STUMP
#     mp = stumpy.stump(ts_concat, m=motif_len)
    
#     # Estrarre top 3 motif: indici dei valori minimi del matrix profile
#     top3_motif_idx = np.argsort(mp[:, 0])[:3]
#     print(f"Top 3 motif start indices: {top3_motif_idx}")
    
#     # Confronto DTW shapelet vs motif
#     for shp_idx in topk_shapelets_per_class[int(class_idx)-1]:
#         shp_idx = int(shp_idx)
#         shp = shapelets[shp_idx]
#         print(f"\nShapelet {shp_idx}:")
        
#         for motif_start in top3_motif_idx:
#             motif = ts_concat[motif_start:motif_start+motif_len]
#             distance = dtw.distance(shp, motif)
#             print(f"DTW distance to motif starting at {motif_start}: {distance:.3f}")
            
#             # Plot confronto
#             plt.figure(figsize=(6,3))
#             plt.plot(shp, label='Shapelet')
#             plt.plot(motif, label='Motif')
#             plt.title(f"Classe {class_idx} - Shapelet {shp_idx} vs Motif {motif_start}")
#             plt.legend()
#             plt.show()

# %% [markdown]
# ##### fill con 0

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import stumpy
# from dtaidistance import dtw

# # Supponiamo di avere già:
# # X_train_scaled: array delle serie temporali scalate
# # y_train: array delle etichette
# # X_shp_train: distanze shapelet vs serie temporali
# # shapelets: lista di shapelet estratte

# def top_k_shapelets_per_class_func(X_shp_train, y_train, topk=3):
#     """Calcola le top-k shapelet uniche per classe"""
#     used_shapelets = set()
#     all_topk = []
#     for class_idx in range(1, 6):  # classi 1-5
#         mean_dists = np.array([np.mean(X_shp_train[y_train==class_idx, i]) 
#                                for i in range(X_shp_train.shape[1])])
#         sorted_idx = np.argsort(mean_dists)
        
#         topk_idx = []
#         for idx in sorted_idx:
#             if idx not in used_shapelets:
#                 topk_idx.append(idx)
#                 used_shapelets.add(idx)
#             if len(topk_idx) >= topk:
#                 break
#         all_topk.append(topk_idx)
#     return all_topk

# # Calcolo top 3 shapelet per classe
# topk_shapelets_per_class = top_k_shapelets_per_class_func(X_shp_train, y_train, topk=3)

# # Loop su ciascuna classe
# for class_idx in np.unique(y_train):
#     print(f"\n=== Classe {class_idx} ===")
    
#     # Seleziona le serie della classe
#     X_class = X_train_scaled[y_train == class_idx]
    
#     # Lunghezza dei motif = lunghezza della shapelet più rappresentativa della classe
#     motif_len = shapelets[int(topk_shapelets_per_class[int(class_idx)-1][0])].shape[0]
    
#     # Concatenazione delle serie
#     ts_concat = np.concatenate(X_class)
    
#     # Calcolo matrix profile con STUMP
#     mp = stumpy.stump(ts_concat, m=motif_len)
    
#     # Estrarre top 3 motif basati sui valori minimi del matrix profile
#     top3_motif_idx = np.argsort(mp[:, 0])[:3]
#     print(f"Top 3 motif start indices: {top3_motif_idx}")
    
#     # Confronto DTW shapelet vs motif
#     for shp_idx in topk_shapelets_per_class[int(class_idx)-1]:
#         shp_idx = int(shp_idx)
#         shp = shapelets[shp_idx]
        
#         # Sostituisci eventuali NaN o Inf nella shapelet
#         shp = np.nan_to_num(shp)
        
#         print(f"\nShapelet {shp_idx}:")
#         for motif_start in top3_motif_idx:
#             motif = ts_concat[motif_start:motif_start+motif_len]
            
#             # Controllo lunghezza motif
#             if len(motif) != motif_len:
#                 print(f"Skipping motif at {motif_start} due to incorrect length")
#                 continue
            
#             # Sostituisci NaN o Inf nel motif
#             motif = np.nan_to_num(motif)
            
#             # Calcolo distanza DTW
#             distance = dtw.distance(shp, motif)
#             print(f"DTW distance to motif starting at {motif_start}: {distance:.3f}")
            
#             # Plot confronto
#             plt.figure(figsize=(6,3))
#             plt.plot(shp, label='Shapelet')
#             plt.plot(motif, label='Motif')
#             plt.title(f"Classe {class_idx} - Shapelet {shp_idx} vs Motif {motif_start}")
#             plt.legend()
#             plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import stumpy
from dtaidistance import dtw
from collections import Counter

# Supponiamo di avere già:
# X_train_scaled: array delle serie temporali scalate
# y_train: array delle etichette
# X_shp_train: distanze shapelet vs serie temporali
# shapelets: lista di shapelet estratte

def top_k_shapelets_per_class_func(X_shp_train, y_train, topk=3):
    """Calcola le top-k shapelet uniche per classe"""
    used_shapelets = set()
    all_topk = []
    for class_idx in np.unique(y_train):  # classi presenti
        mean_dists = np.array([np.mean(X_shp_train[y_train==class_idx, i]) 
                               for i in range(X_shp_train.shape[1])])
        sorted_idx = np.argsort(mean_dists)
        
        topk_idx = []
        for idx in sorted_idx:
            if idx not in used_shapelets:
                topk_idx.append(idx)
                used_shapelets.add(idx)
            if len(topk_idx) >= topk:
                break
        all_topk.append(topk_idx)
    return all_topk

# Calcolo top 3 shapelet per classe
topk_shapelets_per_class = top_k_shapelets_per_class_func(X_shp_train, y_train, topk=3)

# Loop su ciascuna classe
for class_idx in np.unique(y_train):
    print(f"\n=== Classe {class_idx} ===")
    
    # Seleziona le serie della classe
    X_class = X_train_scaled[y_train == class_idx]
    
    # Concatenazione delle serie
    ts_concat = np.concatenate(X_class)
    
    # Lunghezza dei motif = lunghezza della shapelet più rappresentativa della classe
    motif_len = shapelets[int(topk_shapelets_per_class[int(class_idx)-1][0])].shape[0]
    
    # Calcolo matrix profile con STUMP
    mp = stumpy.stump(ts_concat, m=motif_len)
    
    # Trova i candidati motif (indici con distanza più bassa)
    candidate_idx = np.argsort(mp[:, 0])
    
    # Conta i motif più "frequenti" basandosi sulla vicinanza degli indici
    motif_occurrences = Counter()
    for idx in candidate_idx[:50]:  # consideriamo i 50 migliori
        motif_occurrences[idx] += 1
    
    # Prendi i top 3 motif più frequenti
    top3_motif_idx = [idx for idx, _ in motif_occurrences.most_common(3)]
    print(f"Top 3 motif start indices (più frequenti): {top3_motif_idx}")
    
    # Confronto DTW shapelet vs motif
    for shp_idx in topk_shapelets_per_class[int(class_idx)-1]:
        shp_idx = int(shp_idx)
        shp = shapelets[shp_idx]
        print(f"\nShapelet {shp_idx}:")
        
        for motif_start in top3_motif_idx:
            motif = ts_concat[motif_start:motif_start+motif_len]
            distance = dtw.distance(shp, motif)
            print(f"DTW distance to motif starting at {motif_start}: {distance:.3f}")
            
            # Plot confronto
            plt.figure(figsize=(6,3))
            plt.plot(shp, label='Shapelet')
            plt.plot(motif, label='Motif')
            plt.title(f"Classe {class_idx} - Shapelet {shp_idx} vs Motif {motif_start}")
            plt.legend()
            plt.show()
# Out:
# === Classe 0.0 ===
# Exception ignored on calling ctypes callback function: <function ExecutionEngine._raw_object_cache_notify at 0x000002072C4D0EA0>
# Traceback (most recent call last):
#   File "c:\Users\Gagia\anaconda3\Lib\site-packages\llvmlite\binding\executionengine.py", line 178, in _raw_object_cache_notify
#     def _raw_object_cache_notify(self, data):
#
# KeyboardInterrupt:
# Top 3 motif start indices (più frequenti): [155, 455, 156]
#
# Shapelet 17:
# DTW distance to motif starting at 155: nan
# DTW distance to motif starting at 455: nan
# DTW distance to motif starting at 156: nan
# Shapelet 11:
# DTW distance to motif starting at 155: nan
# DTW distance to motif starting at 455: nan
# DTW distance to motif starting at 156: nan
# Shapelet 9:
# DTW distance to motif starting at 155: nan
# DTW distance to motif starting at 455: nan
# DTW distance to motif starting at 156: nan
# === Classe 1.0 ===
# Top 3 motif start indices (più frequenti): [4400, 800, 801]
#
# Shapelet 3:
# DTW distance to motif starting at 4400: nan
# DTW distance to motif starting at 800: nan
# DTW distance to motif starting at 801: nan
# Shapelet 30:
# DTW distance to motif starting at 4400: nan
# DTW distance to motif starting at 800: nan
# DTW distance to motif starting at 801: nan
# Shapelet 14:
# DTW distance to motif starting at 4400: nan
# DTW distance to motif starting at 800: nan
# DTW distance to motif starting at 801: nan
# === Classe 2.0 ===
# Top 3 motif start indices (più frequenti): [3900, 6500, 3901]
#
# Shapelet 1:
# DTW distance to motif starting at 3900: nan
# DTW distance to motif starting at 6500: nan
# DTW distance to motif starting at 3901: nan
# Shapelet 0:
# DTW distance to motif starting at 3900: nan
# DTW distance to motif starting at 6500: nan
# DTW distance to motif starting at 3901: nan
# Shapelet 13:
# DTW distance to motif starting at 3900: nan
# DTW distance to motif starting at 6500: nan
# DTW distance to motif starting at 3901: nan
# === Classe 3.0 ===
# Top 3 motif start indices (più frequenti): [13700, 8300, 13699]
#
# Shapelet 19:
# DTW distance to motif starting at 13700: nan
# DTW distance to motif starting at 8300: nan
# DTW distance to motif starting at 13699: nan
# Shapelet 7:
# DTW distance to motif starting at 13700: nan
# DTW distance to motif starting at 8300: nan
# DTW distance to motif starting at 13699: nan
# Shapelet 28:
# DTW distance to motif starting at 13700: nan
# DTW distance to motif starting at 8300: nan
# DTW distance to motif starting at 13699: nan
# === Classe 4.0 ===
# Top 3 motif start indices (più frequenti): [18700, 24700, 24699]
#
# Shapelet 44:
# DTW distance to motif starting at 18700: 1.700
# DTW distance to motif starting at 24700: 1.728
# DTW distance to motif starting at 24699: 1.334
# Shapelet 10:
# DTW distance to motif starting at 18700: nan
# DTW distance to motif starting at 24700: nan
# DTW distance to motif starting at 24699: nan
# Shapelet 2:
# DTW distance to motif starting at 18700: nan
# DTW distance to motif starting at 24700: nan
# DTW distance to motif starting at 24699: nan

# %% [markdown]
# ### MOTIFS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matrixprofile import *
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
data = pd.read_csv('df_finale.csv')

# %%
data
# Out:
#              0         1         2         3         4         5         6  \
# 0     3.203808  3.310528  3.080549  2.714583  2.409941  1.993775  1.583635
# 1     1.641869  1.789420  1.837915  1.826346  1.841613  1.608536  1.322736
# 2     2.146533  2.074483  1.922000  1.688202  1.367001  1.099541  0.879503
# 3     1.244228  0.974971  0.792436  0.658828  0.110609 -0.230373 -0.290343
# 4     2.958126  2.791581  2.692438  2.631157  2.300224  2.052480  1.904554
# ...        ...       ...       ...       ...       ...       ...       ...
# 1129  3.930861  3.678304  3.339795  2.963937  2.483528  2.027932  1.564115
# 1130  2.917085  2.810270  2.618698  2.314326  2.073896  2.056742  1.890531
# 1131  3.558092  3.264517  2.947922  2.588963  2.087472  1.656590  1.244943
# 1132  3.468692  3.669017  3.510363  3.077339  2.725131  2.253547  1.699255
# 1133  3.099543  2.884476  2.550007  2.201776  1.863530  1.487211  1.026656
#
#              7         8         9  ...  genre_Musical  genre_Mystery  \
# 0     1.246871  0.796810  0.508554  ...              0              0
# 1     1.058922  0.766201  0.509104  ...              0              0
# 2     0.663925  0.466093  0.366285  ...              0              0
# 3    -0.352859 -0.421936 -0.490316  ...              0              0
# 4     1.740678  1.606702  1.489338  ...              0              0
# ...        ...       ...       ...  ...            ...            ...
# 1129  1.153334  0.836055  0.641848  ...              0              1
# 1130  1.667496  1.459727  1.321335  ...              0              0
# 1131  0.928361  0.700896  0.570797  ...              0              0
# 1132  1.092181  0.427260  0.010953  ...              0              0
# 1133  0.654276  0.386490  0.275012  ...              0              0
#
#       genre_Romance  genre_Sci-Fi  genre_Short  genre_Sport  genre_Thriller  \
# 0                 0             1            0            0               0
# 1                 1             0            0            0               0
# 2                 0             0            0            0               0
# 3                 0             1            0            0               0
# 4                 0             0            0            0               0
# ...             ...           ...          ...          ...             ...
# 1129              0             0            0            0               1
# 1130              0             0            0            0               0
# 1131              0             0            0            0               1
# 1132              0             0            0            0               0
# 1133              0             0            0            0               0
#
#       genre_War  genre_Western  rating_encoded
# 0             0              0             4.0
# 1             0              0             4.0
# 2             0              0             4.0
# 3             0              0             4.0
# 4             0              0             4.0
# ...         ...            ...             ...
# 1129          0              0             2.0
# 1130          0              0             2.0
# 1131          0              0             4.0
# 1132          0              0             4.0
# 1133          0              0             3.0
#
# [1134 rows x 124 columns]

# %%
df_timeseries = data.iloc[:, :100]
classes = data['rating_encoded']

# %%
# Seleziona prime 100 colonne + ultima colonna
df= data.iloc[:, list(range(100)) + [-1]]
df
# Out:
#              0         1         2         3         4         5         6  \
# 0     3.203808  3.310528  3.080549  2.714583  2.409941  1.993775  1.583635
# 1     1.641869  1.789420  1.837915  1.826346  1.841613  1.608536  1.322736
# 2     2.146533  2.074483  1.922000  1.688202  1.367001  1.099541  0.879503
# 3     1.244228  0.974971  0.792436  0.658828  0.110609 -0.230373 -0.290343
# 4     2.958126  2.791581  2.692438  2.631157  2.300224  2.052480  1.904554
# ...        ...       ...       ...       ...       ...       ...       ...
# 1129  3.930861  3.678304  3.339795  2.963937  2.483528  2.027932  1.564115
# 1130  2.917085  2.810270  2.618698  2.314326  2.073896  2.056742  1.890531
# 1131  3.558092  3.264517  2.947922  2.588963  2.087472  1.656590  1.244943
# 1132  3.468692  3.669017  3.510363  3.077339  2.725131  2.253547  1.699255
# 1133  3.099543  2.884476  2.550007  2.201776  1.863530  1.487211  1.026656
#
#              7         8         9  ...        91        92        93  \
# 0     1.246871  0.796810  0.508554  ... -0.773251 -0.785931 -0.803325
# 1     1.058922  0.766201  0.509104  ...  0.091804 -0.046413 -0.296589
# 2     0.663925  0.466093  0.366285  ... -0.758995 -0.769806 -0.782269
# 3    -0.352859 -0.421936 -0.490316  ... -0.366959 -0.498499 -0.525716
# 4     1.740678  1.606702  1.489338  ... -0.646453 -0.645161 -0.645457
# ...        ...       ...       ...  ...       ...       ...       ...
# 1129  1.153334  0.836055  0.641848  ... -0.582350 -0.584734 -0.588441
# 1130  1.667496  1.459727  1.321335  ... -0.688884 -0.696743 -0.702418
# 1131  0.928361  0.700896  0.570797  ... -0.547282 -0.579174 -0.602577
# 1132  1.092181  0.427260  0.010953  ... -0.486256 -0.508885 -0.540992
# 1133  0.654276  0.386490  0.275012  ... -0.663196 -0.670948 -0.680126
#
#             94        95        96        97        98        99  \
# 0    -0.819292 -0.826546 -0.800523 -0.780994 -0.758548 -0.731235
# 1    -0.555315 -0.811598 -0.923964 -0.900554 -0.895424 -0.931546
# 2    -0.789811 -0.797837 -0.803927 -0.801292 -0.798581 -0.795879
# 3    -0.548996 -0.568911 -0.587338 -0.602909 -0.612658 -0.613246
# 4    -0.647903 -0.651366 -0.656044 -0.661063 -0.665579 -0.668798
# ...        ...       ...       ...       ...       ...       ...
# 1129 -0.591204 -0.592680 -0.593513 -0.593650 -0.593869 -0.594236
# 1130 -0.706121 -0.709908 -0.710889 -0.710866 -0.709265 -0.704758
# 1131 -0.644120 -0.707286 -0.765331 -0.802150 -0.828583 -0.841612
# 1132 -0.570104 -0.590912 -0.601979 -0.604438 -0.608394 -0.614915
# 1133 -0.686762 -0.690336 -0.694216 -0.699345 -0.702733 -0.701187
#
#       rating_encoded
# 0                4.0
# 1                4.0
# 2                4.0
# 3                4.0
# 4                4.0
# ...              ...
# 1129             2.0
# 1130             2.0
# 1131             4.0
# 1132             4.0
# 1133             3.0
#
# [1134 rows x 101 columns]

# %%
def extract_motifs_matrix_profile(time_series, motif_length=20, max_motifs=5):
    """
    Estrae motifs usando matrixProfile con stomp
    """
    # Calcola matrix profile usando stomp
    profile = matrixProfile.stomp(time_series, motif_length)
    
    # Estrai motifs
    mtfs, motif_d = motifs.motifs(time_series, profile, max_motifs=max_motifs)
    
    # Estrai le subsequenze motif dalla time series
    extracted_motifs = []
    
    for motif_indices in mtfs:
        if len(motif_indices) > 0:
            # Prendi il primo indice del motif
            start_idx = motif_indices[0]
            motif_array = time_series[start_idx:start_idx + motif_length]
            extracted_motifs.append(motif_array)
    
    return extracted_motifs

# %%
def process_time_series_dataset(df, motif_length=20, max_motifs_per_series=5):
    """
    Processa un dataset di time series per estrarre motifs usando matrixProfile
    
    Parameters:
    df: DataFrame con prime 100 colonne come timestamps e class_label dopo
    motif_length: lunghezza dei motifs da estrarre (parametro m)
    max_motifs_per_series: numero massimo di motifs per serie
    """
    
    # Separa time series data e class labels
    time_series_cols = df_timeseries  # Prime 100 colonne
    class_col = classes  # Colonna 101 (class_label)
    
    motif_dataset = []
    
    for series_id in range(len(df)):
    # Estrai la time series dalla riga series_id
        time_series = df.iloc[series_id, :100].values  # Prime 100 colonne della riga
        class_label = df.iloc[series_id, 100]  # Colonna 101 della riga
       
       
        extracted_motifs = extract_motifs_matrix_profile(time_series, motif_length, 
                                                       max_motifs_per_series)
       
        for motif_array in extracted_motifs:
            motif_dict = {
                'motif': motif_array,
                'class': class_label,
                'series_id': series_id
            }
            motif_dataset.append(motif_dict)
    
    return motif_dataset

# %%
motifs_dataset = process_time_series_dataset(df, motif_length=7, max_motifs_per_series=5)

# %%
df_motifs = pd.DataFrame(motifs_dataset)
grouped = df_motifs.groupby('class')

# %%
from dtaidistance import dtw

def avg_similarity(motif, motif_list):
    return np.mean([dtw.distance(motif, other) for other in motif_list])

# %%
top_motifs = {}
for cls, group in grouped:
    motifs = group['motif'].tolist()
    scores = [avg_similarity(m, motifs) for m in motifs]
    top_indices = np.argsort(scores)[:3]
    top_motifs[cls] = top_indices

# %%
top_motifs
# Out:
# {0.0: array([ 9,  0, 19], dtype=int64),
#  1.0: array([427, 348, 260], dtype=int64),
#  2.0: array([981, 787, 156], dtype=int64),
#  3.0: array([723, 290, 195], dtype=int64),
#  4.0: array([1072, 1293,  403], dtype=int64)}

# %%
import numpy as np
from tslearn.metrics import dtw
from scipy.signal import resample

# --- Funzione di utilità per resampling ---
def resample_to_same_length(a, b):
    if len(a) < len(b):
        a_res = resample(a, len(b))
        return a_res, b
    elif len(b) < len(a):
        b_res = resample(b, len(a))
        return a, b_res
    else:
        return a, b

# --- Confronto top-3 motifs (già selezionati) vs shapelets ---
def compare_top3_indices_to_shapelets(top_motifs_indices, top_shapelets, shapelet_model, motif_dataset):
    results = {}
    learned_shapelets = shapelet_model.shapelets_

    for cls, indices in top_motifs_indices.items():
        # Recupera i motifs dai loro indici
        motifs = [motif_dataset[idx]['motif'] for idx in indices]
        
        # Shapelets top-k per classe
        shapelet_idxs = top_shapelets[cls]
        shps = [learned_shapelets[i].ravel() for i in shapelet_idxs]

        sim_matrix_dtw = np.zeros((len(motifs), len(shps)))
        sim_matrix_corr = np.zeros((len(motifs), len(shps)))

        for i, motif in enumerate(motifs):
            for j, shp in enumerate(shps):
                # DTW
                sim_matrix_dtw[i, j] = dtw(motif, shp)

                # Correlazione con resampling
                m_res, s_res = resample_to_same_length(motif, shp)
                m_res -= np.mean(m_res)
                s_res -= np.mean(s_res)
                denom = (np.linalg.norm(m_res) * np.linalg.norm(s_res))
                corr = np.dot(m_res, s_res) / denom if denom > 0 else 0
                sim_matrix_corr[i, j] = corr

        results[cls] = {
            "dtw": sim_matrix_dtw,
            "correlation": sim_matrix_corr,
            "motifs_indices": indices,
            "shapelet_idxs": shapelet_idxs
        }

    return results

# --- Report leggibile ---
def print_comparison_report(results):
    for cls, sims in results.items():
        print(f"\nClasse {cls}:")
        dtw_mat = sims["dtw"]
        corr_mat = sims["correlation"]
        motifs_indices = sims["motifs_indices"]
        shapelet_idxs = sims["shapelet_idxs"]

        for i, motif_idx in enumerate(motifs_indices):
            best_j_dtw = np.argmin(dtw_mat[i])
            best_j_corr = np.argmax(corr_mat[i])
            print(f" Motif {motif_idx}:")
            print(f"   -> più simile a Shapelet {shapelet_idxs[best_j_dtw]} con DTW={dtw_mat[i,best_j_dtw]:.4f}")
            print(f"   -> più correlato a Shapelet {shapelet_idxs[best_j_corr]} con Corr={corr_mat[i,best_j_corr]:.4f}")

# %%
results = compare_top3_indices_to_shapelets(top_motifs, result, shp_model, motifs_dataset)

# Stampa report
print_comparison_report(results)
# Out:
# Classe 0.0:
#  Motif 9:
#    -> più simile a Shapelet 3 con DTW=0.5264
#    -> più correlato a Shapelet 3 con Corr=0.8875
#  Motif 0:
#    -> più simile a Shapelet 3 con DTW=7.5712
#    -> più correlato a Shapelet 3 con Corr=0.9561
#  Motif 19:
#    -> più simile a Shapelet 3 con DTW=5.7450
#    -> più correlato a Shapelet 3 con Corr=0.8782
#
# Classe 1.0:
#  Motif 427:
#    -> più simile a Shapelet 30 con DTW=4.5511
#    -> più correlato a Shapelet 3 con Corr=0.8816
#  Motif 348:
#    -> più simile a Shapelet 3 con DTW=0.6596
#    -> più correlato a Shapelet 14 con Corr=-0.6480
#  Motif 260:
#    -> più simile a Shapelet 3 con DTW=0.4824
#    -> più correlato a Shapelet 3 con Corr=0.9096
#
# Classe 2.0:
#  Motif 981:
#    -> più simile a Shapelet 3 con DTW=1.1360
#    -> più correlato a Shapelet 3 con Corr=0.9005
#  Motif 787:
#    -> più simile a Shapelet 14 con DTW=1.7934
#    -> più correlato a Shapelet 3 con Corr=0.8878
#  Motif 156:
#    -> più simile a Shapelet 1 con DTW=0.8588
#    -> più correlato a Shapelet 1 con Corr=0.6755
#
# Classe 3.0:
#  Motif 723:
#    -> più simile a Shapelet 3 con DTW=1.1720
#    -> più correlato a Shapelet 3 con Corr=0.8836
#  Motif 290:
#    -> più simile a Shapelet 3 con DTW=8.0716
#    -> più correlato a Shapelet 3 con Corr=0.9128
#  Motif 195:
#    -> più simile a Shapelet 3 con DTW=1.2059
#    -> più correlato a Shapelet 3 con Corr=0.9163
#
# Classe 4.0:
#  Motif 1072:
#    -> più simile a Shapelet 14 con DTW=0.5855
#    -> più correlato a Shapelet 3 con Corr=0.9497
#  Motif 1293:
#    -> più simile a Shapelet 1 con DTW=1.1387
#    -> più correlato a Shapelet 1 con Corr=0.7659
#  Motif 403:
#    -> più simile a Shapelet 14 con DTW=1.0723
#    -> più correlato a Shapelet 3 con Corr=0.8817

# %% [markdown]
# ### approccio 2

# %%
X = data.iloc[:, list(range(100))]
y = data["rating_encoded"]

# %%
df_timestamp_class = data.iloc[:, list(range(100)) + [-1]]

# %%
# import numpy as np
# from tslearn.metrics import dtw
# from collections import defaultdict

# # --- Calcolo distanza media motifs ↔ classi ---
# def motif_class_profiles(motif_dataset, X, y, metric="dtw"):
#     """
#     Calcola per ciascun motif un profilo di distanza media per classe.
    
#     Parameters
#     ----------
#     motif_dataset : list of dict
#         Ogni dict ha 'motif', 'class', 'series_id'
#     X : ndarray shape (n_samples, series_length)
#         Serie temporali originali
#     y : ndarray shape (n_samples,)
#         Etichette di classe
#     metric : str
#         'dtw' oppure 'corr' per similarità
    
#     Returns
#     -------
#     profiles : dict
#         motif_idx -> {classe: distanza_media}
#     """
#     classes = np.unique(y)
#     profiles = {}
    
#     for idx, motif_entry in enumerate(motif_dataset):
#         motif = motif_entry['motif']
#         profiles[idx] = {}
        
#         for c in classes:
#             # Seleziona serie della classe c
#             class_series = X[y == c]
            
#             dists = []
#             for ts in class_series:
#                 # Prendo finestre della stessa lunghezza del motif
#                 subseq = ts[:len(motif)]  # semplice, ma puoi fare sliding window
#                 if metric == "dtw":
#                     d = dtw(motif, subseq)
#                 else:
#                     # correlazione
#                     denom = (np.linalg.norm(motif) * np.linalg.norm(subseq))
#                     d = np.dot(motif, subseq) / denom if denom > 0 else 0
#                     d = 1 - d  # trasformo in distanza
#                 dists.append(d)
            
#             profiles[idx][c] = np.mean(dists)
    
#     return profiles


# # --- Ordina motifs per classe ---
# def top_motifs_by_class(profiles, top_k=3):
#     """
#     Ordina motifs in base alla distanza media per ciascuna classe.
#     """
#     classes = list(next(iter(profiles.values())).keys())
#     top = {}
#     for c in classes:
#         # prendi tuple (motif_idx, distanza_media)
#         motif_scores = [(m_idx, d[c]) for m_idx, d in profiles.items()]
#         # ordina crescente (min distanza = più vicino alla classe)
#         motif_scores = sorted(motif_scores, key=lambda x: x[1])
#         top[c] = motif_scores[:top_k]
#     return top


# # --- Matching motifs vs shapelets ---
# def match_motifs_shapelets(top_motifs, top_shapelets):
#     """
#     Confronta i ranking motifs vs shapelets per ogni classe.
    
#     top_motifs: dict {classe -> [(motif_idx, dist), ...]}
#     top_shapelets: dict {classe -> [shapelet_idx, ...]} già calcolati
    
#     Output: report di matching
#     """
#     report = {}
#     for c in top_motifs:
#         motif_list = [m for m, _ in top_motifs[c]]
#         shapelet_list = top_shapelets.get(c, [])
        
#         overlap = set(motif_list).intersection(set(shapelet_list))
#         report[c] = {
#             "motifs_top": motif_list,
#             "shapelets_top": shapelet_list,
#             "overlap": list(overlap)
#         }
#     return report

# %%
# # 1. Calcola profili motifs ↔ classi
# profiles = motif_class_profiles(motifs_dataset, X, y, metric="dtw")

# # 2. Trova i top motifs più vicini per ciascuna classe
# top_motifs = top_motifs_by_class(profiles, top_k=3)

# # 3. Confronta con i top shapelets già noti
# report = match_motifs_shapelets(top_motifs, results)

# # 4. Stampa risultati
# for c, r in report.items():
#     print(f"\nClasse {c}:")
#     print(f" Top motifs: {r['motifs_top']}")
#     print(f" Top shapelets: {r['shapelets_top']}")
#     print(f" Overlap: {r['overlap']}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 2
#       1 # 1. Calcola profili motifs ↔ classi
# ----> 2 profiles = motif_class_profiles(motifs_dataset, X, y, metric="dtw")
#       4 # 2. Trova i top motifs più vicini per ciascuna classe
#       5 top_motifs = top_motifs_by_class(profiles, top_k=3)
#
# Cell In[44], line 42, in motif_class_profiles(motif_dataset, X, y, metric)
#      40 subseq = ts[:len(motif)]  # semplice, ma puoi fare sliding window
#      41 if metric == "dtw":
# ---> 42     d = dtw(motif, subseq)
#      43 else:
#      44     # correlazione
#      45     denom = (np.linalg.norm(motif) * np.linalg.norm(subseq))
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\tslearn\metrics\dtw_variants.py:788, in dtw(s1, s2, global_constraint, sakoe_chiba_radius, itakura_max_slope, be)
#     786 be = instantiate_backend(be, s1, s2)
#     787 s1 = to_time_series(s1, remove_nans=True, be=be)
# --> 788 s2 = to_time_series(s2, remove_nans=True, be=be)
#     790 if len(s1) == 0 or len(s2) == 0:
#     791     raise ValueError(
#     792         "One of the input time series contains only nans or has zero length."
#     793     )
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\tslearn\utils\utils.py:183, in to_time_series(ts, remove_nans, be)
#     181     ts_out = be.cast(ts_out, dtype=float)
#     182 if remove_nans:
# --> 183     ts_out = ts_out[: ts_size(ts_out, be=be)]
#     184 return ts_out
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\tslearn\utils\utils.py:464, in ts_size(ts, be)
#     423 """Returns actual time series size.
#     424
#     425 Final timesteps that have `NaN` values for all dimensions will be removed
#    (...)
#     461 3
#     462 """
#     463 be = instantiate_backend(be, ts)
# --> 464 ts_ = to_time_series(ts, be=be)
#     465 sz = be.shape(ts_)[0]
#     466 while sz > 0 and be.all(be.isnan(ts_[sz - 1])):
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\tslearn\utils\utils.py:177, in to_time_series(ts, remove_nans, be)
#     134 """Transforms a time series so that it fits the format used in ``tslearn``
#     135 models.
#     136
#    (...)
#     174 to_time_series_dataset : Transforms a dataset of time series
#     175 """
#     176 be = instantiate_backend(be, ts)
# --> 177 ts_out = be.array(ts)
#     178 if ts_out.ndim <= 1:
#     179     ts_out = be.reshape(ts_out, (-1, 1))
#
# KeyboardInterrupt:

# %% [markdown]
# ### codice luca in chat

# %%
# from dtaidistance import dtw

# # Dizionari con top 3 shapelet e motif per ogni classe
# shapelets_by_class = results
 
# motifs_by_class = top_motifs
 
# # Funzione per contare le occorrenze con DTW
# def count_dtw_matches(series, pattern, threshold):
#     count = 0
#     plen = len(pattern)
#     for i in range(len(series) - plen + 1):
#         window = series[i:i+plen]
#         dist = dtw.distance(window, pattern)
#         if dist < threshold:
#             count += 1
#     return count
 
# # Analisi per classe
# analysis = {}
 
# for cls in shapelets_by_class:
#     shapelets = shapelets_by_class[cls]
#     motifs = motifs_by_class[cls]
#     # Seleziona solo le serie temporali della classe corrente
#     mask = df_timestamp_class == cls
#     df_cls = df[mask]
#     shapelet_counts = []
#     motif_counts = []
 
#     for _, row in df_cls.iterrows():
#         series = row.values.astype(float)
#         s_counts = [count_dtw_matches(series, s, threshold=10.0) for s in shapelets]
#         m_counts = [count_dtw_matches(series, m, threshold=10.0) for m in motifs]
#         shapelet_counts.append(s_counts)
#         motif_counts.append(m_counts)
 
#     analysis[cls] = {
#         'shapelet_counts': np.array(shapelet_counts),
#         'motif_counts': np.array(motif_counts)
#     }
 
# # Visualizza i risultati per una classe
# for cls in analysis:
#     print(f"\n🔍 Classe: {cls}")
#     print("📊 Occorrenze shapelet:")
#     print(analysis[cls]['shapelet_counts'])
#     print("🔗 Occorrenze motif:")
#     print(analysis[cls]['motif_counts'])
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[49], line 33
#      31 for _, row in df_cls.iterrows():
#      32     series = row.values.astype(float)
# ---> 33     s_counts = [count_dtw_matches(series, s, threshold=10.0) for s in shapelets]
#      34     m_counts = [count_dtw_matches(series, m, threshold=10.0) for m in motifs]
#      35     shapelet_counts.append(s_counts)
#
# Cell In[49], line 33, in <listcomp>(.0)
#      31 for _, row in df_cls.iterrows():
#      32     series = row.values.astype(float)
# ---> 33     s_counts = [count_dtw_matches(series, s, threshold=10.0) for s in shapelets]
#      34     m_counts = [count_dtw_matches(series, m, threshold=10.0) for m in motifs]
#      35     shapelet_counts.append(s_counts)
#
# Cell In[49], line 14, in count_dtw_matches(series, pattern, threshold)
#      12 for i in range(len(series) - plen + 1):
#      13     window = series[i:i+plen]
# ---> 14     dist = dtw.distance(window, pattern)
#      15     if dist < threshold:
#      16         count += 1
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\dtaidistance\dtw.py:337, in distance(s1, s2, only_ub, **kwargs)
#     334     dtw[i1 * length] = 0
#     335 for j in range(j_start, j_end):
#     336     # d = (s1[i] - s2[j])**2
# --> 337     d = idist_fn(s1[i], s2[j])
#     338     if d > s.adj_max_step:
#     339         continue
#
# File c:\Users\Gagia\anaconda3\Lib\site-packages\dtaidistance\innerdistance.py:48, in SquaredEuclidean.inner_dist(x, y)
#      46 @staticmethod
#      47 def inner_dist(x, y):
# ---> 48     return (x - y) ** 2
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('float64'), dtype('<U1')) -> None

# %%
import numpy as np

motif_len = 7  # lunghezza fissata del motif

motifs_by_class_real = {
    cls: [np.array(motifs_dataset[idx]["motif"], dtype=float) for idx in idxs]
    for cls, idxs in top_motifs.items()
}
motifs_by_class_real
# Out:
# {0.0: [array([ 0.52269398,  0.44888558,  0.32348626,  0.16000622,  0.03138061,
#          -0.05886774, -0.10247116]),
#   array([3.20380752, 3.31052783, 3.08054906, 2.71458332, 2.40994107,
#          1.99377548, 1.58363534]),
#   array([3.20689624, 2.86544761, 2.36223283, 1.91464684, 1.49474994,
#          1.11874235, 0.78176021])],
#  1.0: [array([2.82709373, 2.42939925, 1.9642509 , 1.50275742, 0.9839896 ,
#          0.56345998, 0.27856069]),
#   array([-0.2666326 , -0.23598624, -0.1691162 , -0.06187982,  0.09525527,
#           0.20630301,  0.25842654]),
#   array([ 0.2358561 ,  0.17183695,  0.07958548, -0.04799788, -0.21095908,
#          -0.30961364, -0.35310316])],
#  2.0: [array([ 0.06952303, -0.02491911, -0.17067132, -0.38639947, -0.5621544 ,
#          -0.69860523, -0.78021137]),
#   array([ 1.28215271,  1.05506351,  0.73612995,  0.31132028, -0.04478522,
#          -0.2991001 , -0.44626125]),
#   array([-0.26802007, -0.2204929 , -0.14067699,  0.01778415,  0.28281164,
#           0.49237371,  0.63823317])],
#  3.0: [array([-0.32161945, -0.3392823 , -0.36439273, -0.39677769, -0.42242351,
#          -0.44164122, -0.45268609]),
#   array([3.92820484, 3.64778547, 3.31535881, 2.94517129, 2.33812027,
#          1.85777668, 1.46450251]),
#   array([-0.28247171, -0.30489648, -0.35092928, -0.41670927, -0.47214282,
#          -0.5228869 , -0.56412349])],
#  4.0: [array([ 0.36490577,  0.39133942,  0.33061134,  0.24220474,  0.12048136,
#          -0.04909968, -0.19476837]),
#   array([-0.81378273, -0.71416271, -0.55205304, -0.3364916 , -0.10412201,
#           0.10689274,  0.23114141]),
#   array([ 8.08915120e-01,  6.62841773e-01,  4.75627769e-01,  2.06803503e-01,
#           1.79344360e-04, -1.50373704e-01, -2.17492601e-01])]}

# %%
import numpy as np

# Supponiamo che il modello sia chiamato shp_model
# e che abbia un attributo shapelets_ con dentro le shapelet stesse
all_shapelets = shp_model.shapelets_

# Ora costruiamo lo stesso dizionario "real" come per i motifs
shapelets_by_class_real = {
    cls: [np.array(all_shapelets[idx], dtype=float) for idx in idxs]
    for cls, idxs in result.items()
}
shapelets_by_class_real
# Out:
# {0.0: [array([[0.29442924],
#          [0.3218888 ],
#          [0.32839409],
#          [0.31210548],
#          [0.28356338],
#          [0.25806275],
#          [0.23806188],
#          [0.21571048],
#          [0.20071203],
#          [0.20997469]]),
#   array([[0.59522057],
#          [0.57707745],
#          [0.57358199],
#          [0.57360429],
#          [0.51034403],
#          [0.38636029],
#          [0.34286037],
#          [0.35060734],
#          [0.36093172],
#          [0.33298135],
#          [0.29295382],
#          [0.30189976],
#          [0.31017852],
#          [0.30012545],
#          [0.28891623],
#          [0.2829746 ],
#          [0.28236672],
#          [0.26367772],
#          [0.22167782],
#          [0.17132987],
#          [0.16925561],
#          [0.20133853],
#          [0.21951029],
#          [0.21291538],
#          [0.15916754],
#          [0.10540733],
#          [0.1321647 ],
#          [0.17218222],
#          [0.18203019],
#          [0.16439803],
#          [0.15537755],
#          [0.14926341],
#          [0.11589184],
#          [0.08024526],
#          [0.06380092],
#          [0.07568358],
#          [0.13649583],
#          [0.15977103],
#          [0.11255527],
#          [0.02675947],
#          [0.02104402],
#          [0.06330116],
#          [0.06751983],
#          [0.06983264],
#          [0.07474268],
#          [0.08049997],
#          [0.08276848],
#          [0.08049503],
#          [0.08086928],
#          [0.08710454],
#          [0.12152206],
#          [0.14748213],
#          [0.13332944],
#          [0.11396703],
#          [0.12533745],
#          [0.15157157],
#          [0.14581501],
#          [0.12072937],
#          [0.11056621],
#          [0.10692903],
#          [0.11396884],
#          [0.12807587],
#          [0.14207488],
#          [0.15833503],
#          [0.17721382],
#          [0.20657234],
#          [0.21296698],
#          [0.19827606],
#          [0.18322989],
#          [0.17711121]]),
#   array([[0.28279316],
#          [0.30996454],
#          [0.33445948],
#          [0.33938715],
#          [0.33779538],
#          [0.3202188 ],
#          [0.27449325],
#          [0.23393328],
#          [0.20177828],
#          [0.18575515],
#          [0.17849359],
#          [0.16933218],
#          [0.15336701],
#          [0.15102988],
#          [0.17304482],
#          [0.22166146],
#          [0.25903577],
#          [0.26677418],
#          [0.26605475],
#          [0.25594679],
#          [0.23282579],
#          [0.20301709],
#          [0.17052823],
#          [0.14465648],
#          [0.12943715],
#          [0.11986483],
#          [0.1252194 ],
#          [0.1399893 ],
#          [0.17376995],
#          [0.22520305]])],
#  1.0: [array([[0.29442924],
#          [0.3218888 ],
#          [0.32839409],
#          [0.31210548],
#          [0.28356338],
#          [0.25806275],
#          [0.23806188],
#          [0.21571048],
#          [0.20071203],
#          [0.20997469]]),
#   array([[0.28279316],
#          [0.30996454],
#          [0.33445948],
#          [0.33938715],
#          [0.33779538],
#          [0.3202188 ],
#          [0.27449325],
#          [0.23393328],
#          [0.20177828],
#          [0.18575515],
#          [0.17849359],
#          [0.16933218],
#          [0.15336701],
#          [0.15102988],
#          [0.17304482],
#          [0.22166146],
#          [0.25903577],
#          [0.26677418],
#          [0.26605475],
#          [0.25594679],
#          [0.23282579],
#          [0.20301709],
#          [0.17052823],
#          [0.14465648],
#          [0.12943715],
#          [0.11986483],
#          [0.1252194 ],
#          [0.1399893 ],
#          [0.17376995],
#          [0.22520305]]),
#   array([[0.59522057],
#          [0.57707745],
#          [0.57358199],
#          [0.57360429],
#          [0.51034403],
#          [0.38636029],
#          [0.34286037],
#          [0.35060734],
#          [0.36093172],
#          [0.33298135],
#          [0.29295382],
#          [0.30189976],
#          [0.31017852],
#          [0.30012545],
#          [0.28891623],
#          [0.2829746 ],
#          [0.28236672],
#          [0.26367772],
#          [0.22167782],
#          [0.17132987],
#          [0.16925561],
#          [0.20133853],
#          [0.21951029],
#          [0.21291538],
#          [0.15916754],
#          [0.10540733],
#          [0.1321647 ],
#          [0.17218222],
#          [0.18203019],
#          [0.16439803],
#          [0.15537755],
#          [0.14926341],
#          [0.11589184],
#          [0.08024526],
#          [0.06380092],
#          [0.07568358],
#          [0.13649583],
#          [0.15977103],
#          [0.11255527],
#          [0.02675947],
#          [0.02104402],
#          [0.06330116],
#          [0.06751983],
#          [0.06983264],
#          [0.07474268],
#          [0.08049997],
#          [0.08276848],
#          [0.08049503],
#          [0.08086928],
#          [0.08710454],
#          [0.12152206],
#          [0.14748213],
#          [0.13332944],
#          [0.11396703],
#          [0.12533745],
#          [0.15157157],
#          [0.14581501],
#          [0.12072937],
#          [0.11056621],
#          [0.10692903],
#          [0.11396884],
#          [0.12807587],
#          [0.14207488],
#          [0.15833503],
#          [0.17721382],
#          [0.20657234],
#          [0.21296698],
#          [0.19827606],
#          [0.18322989],
#          [0.17711121]])],
#  2.0: [array([[0.29442924],
#          [0.3218888 ],
#          [0.32839409],
#          [0.31210548],
#          [0.28356338],
#          [0.25806275],
#          [0.23806188],
#          [0.21571048],
#          [0.20071203],
#          [0.20997469]]),
#   array([[0.28279316],
#          [0.30996454],
#          [0.33445948],
#          [0.33938715],
#          [0.33779538],
#          [0.3202188 ],
#          [0.27449325],
#          [0.23393328],
#          [0.20177828],
#          [0.18575515],
#          [0.17849359],
#          [0.16933218],
#          [0.15336701],
#          [0.15102988],
#          [0.17304482],
#          [0.22166146],
#          [0.25903577],
#          [0.26677418],
#          [0.26605475],
#          [0.25594679],
#          [0.23282579],
#          [0.20301709],
#          [0.17052823],
#          [0.14465648],
#          [0.12943715],
#          [0.11986483],
#          [0.1252194 ],
#          [0.1399893 ],
#          [0.17376995],
#          [0.22520305]]),
#   array([[0.44115114],
#          [0.45248055],
#          [0.49637112],
#          [0.54426134],
#          [0.56874752],
#          [0.5698576 ],
#          [0.55457634],
#          [0.55835533],
#          [0.56326991],
#          [0.52640957]])],
#  3.0: [array([[0.29442924],
#          [0.3218888 ],
#          [0.32839409],
#          [0.31210548],
#          [0.28356338],
#          [0.25806275],
#          [0.23806188],
#          [0.21571048],
#          [0.20071203],
#          [0.20997469]]),
#   array([[0.28279316],
#          [0.30996454],
#          [0.33445948],
#          [0.33938715],
#          [0.33779538],
#          [0.3202188 ],
#          [0.27449325],
#          [0.23393328],
#          [0.20177828],
#          [0.18575515],
#          [0.17849359],
#          [0.16933218],
#          [0.15336701],
#          [0.15102988],
#          [0.17304482],
#          [0.22166146],
#          [0.25903577],
#          [0.26677418],
#          [0.26605475],
#          [0.25594679],
#          [0.23282579],
#          [0.20301709],
#          [0.17052823],
#          [0.14465648],
#          [0.12943715],
#          [0.11986483],
#          [0.1252194 ],
#          [0.1399893 ],
#          [0.17376995],
#          [0.22520305]]),
#   array([[0.44115114],
#          [0.45248055],
#          [0.49637112],
#          [0.54426134],
#          [0.56874752],
#          [0.5698576 ],
#          [0.55457634],
#          [0.55835533],
#          [0.56326991],
#          [0.52640957]])],
#  4.0: [array([[0.29442924],
#          [0.3218888 ],
#          [0.32839409],
#          [0.31210548],
#          [0.28356338],
#          [0.25806275],
#          [0.23806188],
#          [0.21571048],
#          [0.20071203],
#          [0.20997469]]),
#   array([[0.28279316],
#          [0.30996454],
#          [0.33445948],
#          [0.33938715],
#          [0.33779538],
#          [0.3202188 ],
#          [0.27449325],
#          [0.23393328],
#          [0.20177828],
#          [0.18575515],
#          [0.17849359],
#          [0.16933218],
#          [0.15336701],
#          [0.15102988],
#          [0.17304482],
#          [0.22166146],
#          [0.25903577],
#          [0.26677418],
#          [0.26605475],
#          [0.25594679],
#          [0.23282579],
#          [0.20301709],
#          [0.17052823],
#          [0.14465648],
#          [0.12943715],
#          [0.11986483],
#          [0.1252194 ],
#          [0.1399893 ],
#          [0.17376995],
#          [0.22520305]]),
#   array([[0.44115114],
#          [0.45248055],
#          [0.49637112],
#          [0.54426134],
#          [0.56874752],
#          [0.5698576 ],
#          [0.55457634],
#          [0.55835533],
#          [0.56326991],
#          [0.52640957]])]}

# %%
import numpy as np
from dtaidistance import dtw
from scipy.signal import resample
import seaborn as sns
import matplotlib.pyplot as plt

# Funzione di normalizzazione z-score
def z_normalize(ts):
    ts = np.array(ts, dtype=float)
    return (ts - ts.mean()) / ts.std()

# Funzione per confrontare motifs vs shapelets di una classe
def compare_class_motifs_shapelets(motifs, shapelets, method="dtw"):
    """
    motifs: lista di array 1D
    shapelets: lista di array 2D (colonna), viene appiattita
    method: "euclidean" o "dtw"
    """
    results = np.zeros((len(motifs), len(shapelets)))
    
    for i, m in enumerate(motifs):
        m_norm = z_normalize(m)
        for j, s in enumerate(shapelets):
            s_arr = z_normalize(s.ravel())
            
            # Resample shapelet se lunghezza diversa
            if len(s_arr) != len(m_norm):
                s_arr = resample(s_arr, len(m_norm))
            
            # Calcolo distanza/similarità
            if method == "euclidean":
                dist = np.linalg.norm(m_norm - s_arr)
            elif method == "dtw":
                dist = dtw.distance(m_norm, s_arr)
            else:
                raise ValueError("Metodo non supportato")
            
            results[i,j] = dist
    return results

# Ciclo su tutte le classi e creo heatmap
for cls in motifs_by_class_real.keys():
    motifs = motifs_by_class_real[cls]
    shapelets = shapelets_by_class_real[cls]
    
    dist_matrix = compare_class_motifs_shapelets(motifs, shapelets, method="dtw")
    
    plt.figure(figsize=(8,6))
    sns.heatmap(dist_matrix, annot=True, fmt=".2f", cmap="coolwarm")
    plt.title(f"Classe {cls} - Distances Motifs vs Shapelets (DTW)")
    plt.xlabel("Shapelets")
    plt.ylabel("Motifs")
    plt.show()

# %%
import numpy as np
from dtaidistance import dtw
from scipy.signal import resample
import seaborn as sns
import matplotlib.pyplot as plt

def compare_class_motifs_shapelets_raw(motifs, shapelets, method="dtw"):
    """
    Confronta motifs e shapelets senza normalizzazione.
    motifs: lista di array 1D
    shapelets: lista di array 2D (colonna)
    method: "euclidean" o "dtw"
    """
    results = np.zeros((len(motifs), len(shapelets)))
    
    for i, m in enumerate(motifs):
        for j, s in enumerate(shapelets):
            s_arr = s.ravel()
            
            # Resample shapelet se lunghezza diversa
            if len(s_arr) != len(m):
                s_arr = resample(s_arr, len(m))
            
            if method == "euclidean":
                dist = np.linalg.norm(m - s_arr)
            elif method == "dtw":
                dist = dtw.distance(m, s_arr)
            else:
                raise ValueError("Metodo non supportato")
            
            results[i,j] = dist
    return results

# Ciclo su tutte le classi e creo heatmap
for cls in motifs_by_class_real.keys():
    motifs = motifs_by_class_real[cls]
    shapelets = shapelets_by_class_real[cls]
    
    dist_matrix = compare_class_motifs_shapelets_raw(motifs, shapelets, method="dtw")
    
    plt.figure(figsize=(8,6))
    sns.heatmap(dist_matrix, annot=True, fmt=".2f", cmap="coolwarm")  # palette modificabile
    plt.title(f"Classe {cls} - Distances Motifs vs Shapelets (DTW, raw values)")
    plt.xlabel("Shapelets")
    plt.ylabel("Motifs")
    plt.show()

# %%
import numpy as np
from scipy.signal import resample
import seaborn as sns
import matplotlib.pyplot as plt

def cosine_similarity(a, b):
    """Calcola la similarità coseno tra due vettori 1D."""
    a = np.array(a, dtype=float)
    b = np.array(b, dtype=float)
    dot = np.dot(a, b)
    norm = np.linalg.norm(a) * np.linalg.norm(b)
    return dot / norm if norm != 0 else 0.0

def compare_class_motifs_shapelets_cosine(motifs, shapelets):
    """
    Confronta motifs e shapelets usando la Cosine Similarity.
    Restituisce una matrice motifs x shapelets con valori [0,1]
    """
    results = np.zeros((len(motifs), len(shapelets)))
    
    for i, m in enumerate(motifs):
        for j, s in enumerate(shapelets):
            s_arr = s.ravel()
            
            # Resample shapelet se lunghezza diversa
            if len(s_arr) != len(m):
                s_arr = resample(s_arr, len(m))
            
            # Calcola cosine similarity
            results[i,j] = cosine_similarity(m, s_arr)
    
    return results

# Ciclo su tutte le classi e creo heatmap
for cls in motifs_by_class_real.keys():
    motifs = motifs_by_class_real[cls]
    shapelets = shapelets_by_class_real[cls]
    
    sim_matrix = compare_class_motifs_shapelets_cosine(motifs, shapelets)
    
    plt.figure(figsize=(8,6))
    sns.heatmap(sim_matrix, annot=True, fmt=".2f", cmap="YlGnBu")  # palette diversa
    plt.title(f"Classe {cls} - Cosine Similarity Motifs vs Shapelets")
    plt.xlabel("Shapelets")
    plt.ylabel("Motifs")
    plt.show()
